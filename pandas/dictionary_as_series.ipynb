# %%
import pandas as pd

# %%
data = {
    "name" : "kalpesh",
    "height" : 121,
    "weight":78
}
val = pd.Series(data)
print(val)
# Out:
# name      kalpesh
# height        121
# weight         78
# dtype: object
